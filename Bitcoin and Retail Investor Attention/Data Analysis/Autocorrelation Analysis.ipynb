# %% [markdown]
# Import used libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.tools.plotting import autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_acf
# Out:
# /Users/Malte/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# # 1. Google SV

# %% [markdown]
# Import used data

# %%
google_queries = pd.DataFrame.from_csv("Google Trends Relative Search Volume.csv")
google_queries.head()
# Out:
#          Week  Relative Search Volume
# 0  2013-04-14                       6
# 1  2013-04-21                       3
# 2  2013-04-28                       3
# 3  2013-05-05                       2
# 4  2013-05-12                       3

# %% [markdown]
# Plot the Autocorrelation

# %%
autocorrelation_plot(google_queries["Relative Search Volume"])
plt.show()
# Out:
# /Users/Malte/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.
#   if __name__ == '__main__':

# %%
plot_acf(google_queries["Relative Search Volume"], lags=20)

# %% [markdown]
# # 2. Bitcoin WAP

# %% [markdown]
# Import used data

# %%
bitcoin_weekly_price = pd.DataFrame.from_csv("Bitcoin Weekly Price Data.csv")
bitcoin_weekly_price.head()
# Out:
#          Date  Weekly Average Price
# 0  2013-04-14             96.677143
# 1  2013-04-21            133.834286
# 2  2013-04-28            121.818571
# 3  2013-05-05            113.905714
# 4  2013-05-12            113.572857

# %% [markdown]
# Plot the Autocorrelation

# %%
autocorrelation_plot(bitcoin_weekly_price["Weekly Average Price"])
plt.show()
# Out:
# /Users/Malte/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.
#   if __name__ == '__main__':

# %%
plot_acf(bitcoin_weekly_price["Weekly Average Price"], lags=20)

# %% [markdown]
# # 3. Bitcoin WAV

# %% [markdown]
# Import used data

# %%
bitcoin_weekly_volume = pd.DataFrame.from_csv("Bitcoin Weekly Volume Data.csv")
bitcoin_weekly_volume.head()
# Out:
#          Date  Average Volume per Week
# 0  2013-04-14             1.815588e+06
# 1  2013-04-21             1.770383e+06
# 2  2013-04-28             1.770067e+06
# 3  2013-05-05             1.154001e+06
# 4  2013-05-12             8.223102e+05

# %% [markdown]
# Plot the Autocorrelation

# %%
autocorrelation_plot(bitcoin_weekly_volume["Average Volume per Week"])
plt.show()
# Out:
# /Users/Malte/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.
#   if __name__ == '__main__':

# %%
plot_acf(bitcoin_weekly_volume["Average Volume per Week"], lags=20)

# %% [markdown]
# # 4. Wikipedia PV

# %% [markdown]
# Import used data

# %%
wikipedia_pageviews = pd.DataFrame.from_csv("Wikipedia Pageview Data.csv")
wikipedia_pageviews.head()
# Out:
#    Pageviews
# 0      12957
# 1       9802
# 2       8307
# 3       8947
# 4       8692

# %% [markdown]
# Plot the Autocorrelation

# %%
autocorrelation_plot(wikipedia_pageviews["Pageviews"])
plt.show()
# Out:
# /Users/Malte/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.
#   if __name__ == '__main__':

# %%
plot_acf(wikipedia_pageviews["Pageviews"], lags=50)

# %% [markdown]
# # 5. Bitcoin DP

# %% [markdown]
# Import used data

# %%
bitcoin_daily_price = pd.DataFrame.from_csv("Bitcoin Daily Price Data.csv")
bitcoin_daily_price.head()
# Out:
#          Date  Daily Closing Price
# 0  2015-07-01               257.62
# 1  2015-07-02               254.54
# 2  2015-07-03               255.92
# 3  2015-07-04               260.20
# 4  2015-07-05               271.50

# %% [markdown]
# Plot the Autocorrelation

# %%
autocorrelation_plot(bitcoin_daily_price["Daily Closing Price"])
plt.show()
# Out:
# /Users/Malte/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.
#   if __name__ == '__main__':

# %%
plot_acf(bitcoin_daily_price["Daily Closing Price"], lags=50)

# %% [markdown]
# # 6. Bitcoin DV

# %% [markdown]
# Import used data

# %%
bitcoin_daily_volume = pd.DataFrame.from_csv("Bitcoin Daily Volume Data.csv")
bitcoin_daily_volume.head()
# Out:
#          Date  Volume (Currency)
# 0  2015-07-01       3.453026e+06
# 1  2015-07-02       2.515779e+06
# 2  2015-07-03       2.331332e+06
# 3  2015-07-04       2.037201e+06
# 4  2015-07-05       5.689203e+06

# %% [markdown]
# Plot the Autocorrelation

# %%
autocorrelation_plot(bitcoin_daily_volume["Volume (Currency)"])
plt.show()
# Out:
# /Users/Malte/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.
#   if __name__ == '__main__':

# %%
plot_acf(bitcoin_daily_volume["Volume (Currency)"], lags=50)
