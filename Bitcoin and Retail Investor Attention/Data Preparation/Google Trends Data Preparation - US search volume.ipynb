# %% [markdown]
# # Preparing Google Search Data

# %% [markdown]
# The data is taken from Google Trends (https://trends.google.com/trends/explore?date=2013-04-13%202018-04-14&q=bitcoin) for the search term "bitcoin".
# It represents the weekly, relative search volume of "bitcoin" (USA, in all categories, web search) from 04/14/2013 - 04/14/2018. (Dates always mark the beginning of the respective week).

# %% [markdown]
# Import used libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Import the CSV file (google_trends_query_bitcoin.csv) containing the search volume data

# %%
google_query_bitcoin_raw = pd.DataFrame.from_csv("google_trends_query_bitcoin.csv")
google_query_bitcoin_finished = google_query_bitcoin_raw.reset_index()

# %% [markdown]
# ## Google weekly search volume

# %%
google_query_bitcoin_finished.head()
# Out:
#         Week  Relative Search Volume
# 0 2013-04-14                       6
# 1 2013-04-21                       3
# 2 2013-04-28                       3
# 3 2013-05-05                       2
# 4 2013-05-12                       3

# %% [markdown]
# ## Safe to CSV for Usage in Data Analysis:

# %% [markdown]
# Safe the dataframe to a csv file ("Google Trends Relative Search Volume") for usage in Data Analysis (see Folder: Data Analysis).
# Code line is marked as a comment here, so that it is not executed (and a csv file created) everytime the notebook is run.

# %%
#google_query_bitcoin_finished.to_csv("Google Trends Relative Search Volume.csv")
